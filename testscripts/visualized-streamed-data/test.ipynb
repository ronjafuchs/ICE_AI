# %%
import cv2
import numpy as np

# %%
observation = None
with open("test", "r") as f:
    image_bytes = f.read()
    print(image_bytes)
    #convert string to bytes
    image_bytes = bytes(image_bytes, 'utf-8')
    print(image_bytes)
    observation = cv2.imdecode(np.frombuffer(image_bytes, np.uint8), -1)
    print(observation)
    print(observation.shape)
# Out:
# ...  x16x12x15xc7!#3Egx84xcc'<ApXx00x00x00x00x03xb1s^rxe3xdcxd6Hx14x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x16aLHeI3x19=x00x00x00x00x00x00x02x00x03xe5xe6xc3x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x00x0
# ...
